# %% [markdown]
# # Лабораторная работа 2-1

# %% [markdown]
# ## 2.1.1: Множества
#
# Напишите функцию, которая находит пересечение двух множеств и печатает их.
# Инициализируйте два множества, например, значениями {13, 25, 37, 45, 13} и {14, 25, 38, 8, 45} и вызовите  функцию.

# %%
def f_peresechenie(m1,m2):
  peresechenie = m1.intersection(m2)
  print(peresechenie)

m1 = {13, 25, 37, 45, 13}
m2 = {14, 25, 38, 8, 45}

f_peresechenie(m1,m2)
# Out:
# {25, 45}

# %% [markdown]
# ## 2.1.2: Dictionaries
#
# * Создайте словарь с двухбуквенными кодами двух федеральных округов России и полными названиями, например, ЦТ: 	Центральный, ЮЖ: Южный.
# * После первоначального создания словаря добавьте в словарь еще два округа.
# * Создайте второй словарь, который сопоставляет коды федеральных округов России с массивом городов в этом округе, например, ЦТ: [Москва, Тверь, Химки, Мытищи].
# * Напишите функцию, которая принимает код федеральных округов, печатает полное название округа и выводит список городов в этом округе.

# %%
fed_okrug = {"ЦТ":"Центральный", "ЮЖ":"Южный"}

# %%
fed_okrug["УР"] = "Уральский"
fed_okrug["СБ"] = "Сибирский"

# %%
print(fed_okrug)
# Out:
# {'ЦТ': 'Центральный', 'ЮЖ': 'Южный', 'УР': 'Уральский', 'СБ': 'Сибирский'}

# %%
fed_okrug_goroda = {"ЦТ":["Москва","Тверь", "Химки", "Мытищи"],
                    "ЮЖ":["Ростов-на-Дону","Волгоград","Краснодар","Астрахань"],
                    "СБ":["Новосибирск", "Омск", "Иркутск", "Кемерово"],
                    "УР":["Курган", "Тюмень", "Челябинск","Екатеренбург"]}
print(fed_okrug_goroda)
# Out:
# {'ЦТ': ['Москва', 'Тверь', 'Химки', 'Мытищи'], 'ЮЖ': ['Ростов-на-Дону', 'Волгоград', 'Краснодар', 'Астрахань'], 'СБ': ['Новосибирск', 'Омск', 'Иркутск', 'Кемерово'], 'УР': ['Курган', 'Тюмень', 'Челябинск', 'Екатеренбург']}

# %%
def about_fed_okrug():
    for k, v in fed_okrug.items():
        print(f'{k}: {v}')
        fed_okrug_goroda[k]
        print('Города:')
        for gorod in fed_okrug_goroda[k]:
            print(gorod)
        print()


about_fed_okrug()
# Out:
# ЦТ: Центральный
# Города:
# Москва
# Тверь
# Химки
# Мытищи
#
# ЮЖ: Южный
# Города:
# Ростов-на-Дону
# Волгоград
# Краснодар
# Астрахань
#
# УР: Уральский
# Города:
# Курган
# Тюмень
# Челябинск
# Екатеренбург
#
# СБ: Сибирский
# Города:
# Новосибирск
# Омск
# Иркутск
# Кемерово

# %% [markdown]
# ## 2.1.3: Objects
#
# Создайте класс `Pet` с параметрами `name, pronoun, animal,` и `pet_response`.
#
# Добавьте метод `pet()`, который печатает ответ, состоящий из элементов, например:
#
# ` Лейла — кошка. Если ее погладить, Лейла мурчит».`
# ` Скаут — собака. Если его погладить, Скаут виляет хвостом.`

# %%
class Pet:
  def __init__(self, name, pronoun, animal, pet_response):
        self.name = name
        self.pronoun = pronoun
        self.animal = animal
        self.pet_response = pet_response

  def pet(self):
    print(f"{self.name} - {self.animal}. Если {self.pronoun} погладить, {self.name} {self.pet_response}")

kesha = Pet("Кеша", "его", "попугай", "чирикает")
kesha.pet()
# Out:
# Кеша - попугай. Если его погладить, Кеша чирикает

# %% [markdown]
# Вот несколько примеров вызовов:

# %%
layla = Pet("Layla", "her", "cat", "purrs")
scout = Pet("Scout", "her", "dog", "wags her tail")

layla.pet()
scout.pet()

# %% [markdown]
# ## 2.1.4: Pandas Series

# %% [markdown]
# Создайте `pandas series`, используя приведенные ниже списки, содержащие названия команд [Российской премьер-лиги](https://ru.wikipedia.org/wiki/%D0%A0%D0%BE%D1%81%D1%81%D0%B8%D0%B9%D1%81%D0%BA%D0%B0%D1%8F_%D0%BF%D1%80%D0%B5%D0%BC%D1%8C%D0%B5%D1%80-%D0%BB%D0%B8%D0%B3%D0%B0) и количество выигранных ими кубка премьер-лиги. Используйте имена как индексы, а победы как данные.
#
#   * После создания списка отсортируйте данные в алфавитном порядке по индексу.
#   * Распечатать обзор статистических свойств ряда. Каково среднее количество побед?
#   * Отфильтровать все команды, выигравшие менее четырех кубков премьер-лиги.
#   * В футбольной команде 11 игроков. Обновите данные, чтобы вместо количества чемпионатов,  отражалось количество побед.
#   * Предположим, что каждая  победа приносила 50 000 долларов США. Обновите данные, чтобы они содержали строку суммы в долларах, включая знак \$. Например, для `Локомотив` это будет соответствовать:
#   ```
#   Тренер Юрий Сёмин  Локомотив $ 600000
#   ```

# %%
import pandas as pd

# %%
teams = ["Юрий Сёмин («Локомотив»)",
         "Олег Романцев («Спартак»)",
         "Сергей Семак («Зенит»)",
         "Валерий Газзаев («Спартак-Алания»)",
         "Леонид Слуцкий (ЦСКА)",
         "Курбан Бердыев («Рубин»)",
         "Лучано Спаллетти («Зенит»)",
         "Андре Виллаш-Боаш («Зенит»)",
         "Дик Адвокат («Зенит»)",
         "Массимо Каррера («Спартак»)",
         "Зико (ЦСКА)",
         "Георгий Ярцев («Спартак»)"]
wins = [12,11,10,10,7,5,4,3,2,2,1,1]

# %%
teamps_pd = pd.Series(wins, index = teams)
print(teamps_pd)
# Out:
# Юрий Сёмин («Локомотив»)              12
# Олег Романцев («Спартак»)             11
# Сергей Семак («Зенит»)                10
# Валерий Газзаев («Спартак-Алания»)    10
# Леонид Слуцкий (ЦСКА)                  7
# Курбан Бердыев («Рубин»)               5
# Лучано Спаллетти («Зенит»)             4
# Андре Виллаш-Боаш («Зенит»)            3
# Дик Адвокат («Зенит»)                  2
# Массимо Каррера («Спартак»)            2
# Зико (ЦСКА)                            1
# Георгий Ярцев («Спартак»)              1
# dtype: int64

# %%
teamps_pd1 = teamps_pd.sort_index() #сортировка по алфавиту
print(teamps_pd1)
# Out:
# Андре Виллаш-Боаш («Зенит»)            3
# Валерий Газзаев («Спартак-Алания»)    10
# Георгий Ярцев («Спартак»)              1
# Дик Адвокат («Зенит»)                  2
# Зико (ЦСКА)                            1
# Курбан Бердыев («Рубин»)               5
# Леонид Слуцкий (ЦСКА)                  7
# Лучано Спаллетти («Зенит»)             4
# Массимо Каррера («Спартак»)            2
# Олег Романцев («Спартак»)             11
# Сергей Семак («Зенит»)                10
# Юрий Сёмин («Локомотив»)              12
# dtype: int64

# %%
print(teamps_pd.describe()) #Обзор статистических свойств ряда
# Out:
# count    12.000000
# mean      5.666667
# std       4.141439
# min       1.000000
# 25%       2.000000
# 50%       4.500000
# 75%      10.000000
# max      12.000000
# dtype: float64

# %%
avg_win = teamps_pd.mean() #среднее количество побед
print(f"Среднее количество побед: {avg_win}")
# Out:
# Среднее количество побед: 5.666666666666667

# %%
f_menee_four = teamps_pd[teamps_pd < 4] #фильтрация по
print(f"Команды, выигравшие менее 4 кубков: \n{f_menee_four}")
# Out:
# Команды, выигравшие менее 4 кубков:
# Андре Виллаш-Боаш («Зенит»)    3
# Дик Адвокат («Зенит»)          2
# Массимо Каррера («Спартак»)    2
# Зико (ЦСКА)                    1
# Георгий Ярцев («Спартак»)      1
# dtype: int64

# %% [markdown]
# Парсинг таблицы из википедии

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = "https://ru.wikipedia.org/wiki/%D0%A0%D0%BE%D1%81%D1%81%D0%B8%D0%B9%D1%81%D0%BA%D0%B0%D1%8F_%D0%BF%D1%80%D0%B5%D0%BC%D1%8C%D0%B5%D1%80-%D0%BB%D0%B8%D0%B3%D0%B0"
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
table = soup.find('span', {'id': 'Тренеры'}).find_next('table')

# %%
df = pd.read_html(str(table))[0]
df
# Out:
#      №                                    Тренер  Всего  Чемпионат  Кубок  \
# 0    1                  Юрий Сёмин («Локомотив»)     12          3      6
# 1    2                 Олег Романцев («Спартак»)     11          8      3
# 2    3                    Сергей Семак («Зенит»)     10          5      1
# 3    4  Валерий Газзаев («Спартак-Алания», ЦСКА)     10          4      4
# 4    5                     Леонид Слуцкий (ЦСКА)      7          3      2
# 5    6                  Курбан Бердыев («Рубин»)      5          2      1
# 6    7                Лучано Спаллетти («Зенит»)      4          2      1
# 7    8               Андре Виллаш-Боаш («Зенит»)      3          1      1
# 8    9                     Дик Адвокат («Зенит»)      2          1      0
# 9    9               Массимо Каррера («Спартак»)      2          1      0
# 10  11                               Зико (ЦСКА)      2          0      1
# 11  12                 Георгий Ярцев («Спартак»)      1          1      0
# 12  13                  Юрий Миронов («Торпедо»)      1          0      1
# 13  13              Константин Бесков («Динамо»)      1          0      1
# 14  13                Анатолий Давыдов («Зенит»)      1          0      1
# 15  13                    Ваит Талгаев («Терек»)      1          0      1
# 16  13            Анатолий Бышовец («Локомотив»)      1          0      1
# 17  13                Миодраг Божович («Ростов»)      1          0      1
# 18  13            Игорь Черевченко («Локомотив»)      1          0      1
# 19  13                Дмитрий Парфёнов («Тосно»)      1          0      1
# 20  13               Марко Николич («Локомотив»)      1          0      1
# 21  13                  Паоло Ваноли («Спартак»)      1          0      1
# 22  13                   Владимир Федотов (ЦСКА)      1          0      1
# 23  24              Властимил Петржела («Зенит»)      1          0      0
# 24  25                        Артур Жорже (ЦСКА)      1          0      0
# 25  25                   Мирча Луческу («Зенит»)      1          0      0
# 26  25                  Виктор Гончаренко (ЦСКА)      1          0      0
#
#     Кубок лиги  Суперкубок
# 0            0           3
# 1            0           0
# 2            0           4
# 3            0           2
# 4            0           2
# 5            0           2
# 6            0           1
# 7            0           1
# 8            0           1
# 9            0           1
# 10           0           1
# 11           0           0
# 12           0           0
# 13           0           0
# 14           0           0
# 15           0           0
# 16           0           0
# 17           0           0
# 18           0           0
# 19           0           0
# 20           0           0
# 21           0           0
# 22           0           0
# 23           1           0
# 24           0           1
# 25           0           1
# 26           0           1

# %%
money = df

# %%
money.drop(('Суперкубок'), axis=1, inplace=True)#последовательно удаляем ненужные столбцы (Чемпионат, Кубок, Кубок лиги, Суперкубок)

# %%
money
# Out:
#      №                                    Тренер  Всего Валюта   Сумма
# 0    1                  Юрий Сёмин («Локомотив»)     12      $  600000
# 1    2                 Олег Романцев («Спартак»)     11      $  550000
# 2    3                    Сергей Семак («Зенит»)     10      $  500000
# 3    4  Валерий Газзаев («Спартак-Алания», ЦСКА)     10      $  500000
# 4    5                     Леонид Слуцкий (ЦСКА)      7      $  350000
# 5    6                  Курбан Бердыев («Рубин»)      5      $  250000
# 6    7                Лучано Спаллетти («Зенит»)      4      $  200000
# 7    8               Андре Виллаш-Боаш («Зенит»)      3      $  150000
# 8    9                     Дик Адвокат («Зенит»)      2      $  100000
# 9    9               Массимо Каррера («Спартак»)      2      $  100000
# 10  11                               Зико (ЦСКА)      2      $  100000
# 11  12                 Георгий Ярцев («Спартак»)      1      $   50000
# 12  13                  Юрий Миронов («Торпедо»)      1      $   50000
# 13  13              Константин Бесков («Динамо»)      1      $   50000
# 14  13                Анатолий Давыдов («Зенит»)      1      $   50000
# 15  13                    Ваит Талгаев («Терек»)      1      $   50000
# 16  13            Анатолий Бышовец («Локомотив»)      1      $   50000
# 17  13                Миодраг Божович («Ростов»)      1      $   50000
# 18  13            Игорь Черевченко («Локомотив»)      1      $   50000
# 19  13                Дмитрий Парфёнов («Тосно»)      1      $   50000
# 20  13               Марко Николич («Локомотив»)      1      $   50000
# 21  13                  Паоло Ваноли («Спартак»)      1      $   50000
# 22  13                   Владимир Федотов (ЦСКА)      1      $   50000
# 23  24              Властимил Петржела («Зенит»)      1      $   50000
# 24  25                        Артур Жорже (ЦСКА)      1      $   50000
# 25  25                   Мирча Луческу («Зенит»)      1      $   50000
# 26  25                  Виктор Гончаренко (ЦСКА)      1      $   50000

# %%
money["Валюта"] = "$"
money["Сумма"] = money["Всего"] * 50000
